# %%
pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-3.6.1-py3-none-any.whl (380 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 1.4 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 7.2 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.30)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.1 colorlog-6.8.2 optuna-3.6.1

# %%
import optuna
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_percentage_error
from sklearn.model_selection import TimeSeriesSplit

# %%
df = pd.read_csv('BNB-USD.csv')

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# %%
df_Close = df[['Close']]
df_Close = df_Close.reset_index(drop=True)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(np.array(df_Close).reshape(-1, 1))

# %%
# Hàm tạo đặc trưng lag
def create_lagged_features(data, n_lags=1):
    df_lags = pd.DataFrame()
    for i in range(n_lags):
        df_lags[f'lag_{i+1}'] = np.roll(data, shift=i+1)
    df_lags['target'] = data
    return df_lags.iloc[n_lags:]

# %%
# Hàm tối ưu hóa sử dụng Optuna
def objective(trial):
    # Gợi ý giá trị cho n_lags và n_estimators
    n_lags = trial.suggest_int('n_lags', 1, 30)                 # Tìm số lượng lag từ 1 đến 30
    n_estimators = trial.suggest_int('n_estimators', 10, 200)   # Tìm số lượng cây từ 10 đến 200

    # Tạo đặc trưng lag
    lagged_data = create_lagged_features(data_scaled.flatten(), n_lags)
    X, y = lagged_data.iloc[:, :-1], lagged_data.iloc[:, -1]

    tscv = TimeSeriesSplit(n_splits=5)
    errors = []

    for train_index, test_index in tscv.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        rf_model = RandomForestRegressor(n_estimators=n_estimators, random_state=42)
        rf_model.fit(X_train, y_train)
        y_pred = rf_model.predict(X_test)

        errors.append(mean_squared_error(y_test, y_pred))

    return np.mean(errors)

# %% [markdown]
# **Tìm kiếm tham số tối ưu**

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)  # Thử nghiệm 50 lần để tìm giá trị tối ưu

# In ra tham số tối ưu
best_params = study.best_params
print(f'Best parameters: {best_params}')
print(f'Best trial value: {study.best_value}')
# Out:
# [I 2024-06-13 03:02:57,356] A new study created in memory with name: no-name-dfc6e91c-e347-4e86-a3f7-995f3020eb32
# [I 2024-06-13 03:03:08,555] Trial 0 finished with value: 0.05020687418249379 and parameters: {'n_lags': 30, 'n_estimators': 100}. Best is trial 0 with value: 0.05020687418249379.
# [I 2024-06-13 03:03:11,165] Trial 1 finished with value: 0.04718732882857381 and parameters: {'n_lags': 12, 'n_estimators': 58}. Best is trial 1 with value: 0.04718732882857381.
# [I 2024-06-13 03:03:12,971] Trial 2 finished with value: 0.04613569074791999 and parameters: {'n_lags': 4, 'n_estimators': 86}. Best is trial 2 with value: 0.04613569074791999.
# [I 2024-06-13 03:03:32,712] Trial 3 finished with value: 0.050272262387122124 and parameters: {'n_lags': 27, 'n_estimators': 198}. Best is trial 2 with value: 0.04613569074791999.
# [I 2024-06-13 03:03:33,236] Trial 4 finished with value: 0.04602332373899307 and parameters: {'n_lags': 1, 'n_estimators': 27}. Best is trial 4 with value: 0.04602332373899307.
# [I 2024-06-13 03:03:44,811] Trial 5 finished with value: 0.050290028709680204 and parameters: {'n_lags': 27, 'n_estimators': 133}. Best is trial 4 with value: 0.04602332373899307.
# [I 2024-06-13 03:03:58,039] Trial 6 finished with value: 0.05029709337266482 and parameters: {'n_lags': 27, 'n_estimators': 143}. Best is trial 4 with value: 0.04602332373899307.
# [I 2024-06-13 03:03:59,415] Trial 7 finished with value: 0.047254365100999576 and parameters: {'n_lags': 7, 'n_estimators': 29}. Best is trial 4 with value: 0.04602332373899307.
# [I 2024-06-13 03:04:04,384] Trial 8 finished with value: 0.04726969448745187 and parameters: {'n_lags': 8, 'n_estimators': 132}. Best is trial 4 with value: 0.04602332373899307.
# [I 2024-06-13 03:04:04,923] Trial 9 finished with value: 0.04727092098506932 and parameters: {'n_lags': 8, 'n_estimators': 15}. Best is trial 4 with value: 0.04602332373899307.
# [I 2024-06-13 03:04:08,496] Trial 10 finished with value: 0.04922301918716136 and parameters: {'n_lags': 19, 'n_estimators': 57}. Best is trial 4 with value: 0.04602332373899307.
# [I 2024-06-13 03:04:09,372] Trial 11 finished with value: 0.04601469301407499 and parameters: {'n_lags': 1, 'n_estimators': 78}. Best is trial 11 with value: 0.04601469301407499.
# [I 2024-06-13 03:04:10,070] Trial 12 finished with value: 0.0460250284291696 and parameters: {'n_lags': 1, 'n_estimators': 60}. Best is trial 11 with value: 0.04601469301407499.
# [I 2024-06-13 03:04:10,477] Trial 13 finished with value: 0.04604436660417131 and parameters: {'n_lags': 1, 'n_estimators': 33}. Best is trial 11 with value: 0.04601469301407499.
# [I 2024-06-13 03:04:16,665] Trial 14 finished with value: 0.04818213523507882 and parameters: {'n_lags': 17, 'n_estimators': 86}. Best is trial 11 with value: 0.04601469301407499.
# [I 2024-06-13 03:04:16,974] Trial 15 finished with value: 0.04617493009992392 and parameters: {'n_lags': 4, 'n_estimators': 12}. Best is trial 11 with value: 0.04601469301407499.
# [I 2024-06-13 03:04:19,081] Trial 16 finished with value: 0.048138674428071536 and parameters: {'n_lags': 13, 'n_estimators': 45}. Best is trial 11 with value: 0.04601469301407499.
# [I 2024-06-13 03:04:23,854] Trial 17 finished with value: 0.04928251719793888 and parameters: {'n_lags': 21, 'n_estimators': 72}. Best is trial 11 with value: 0.04601469301407499.
# [I 2024-06-13 03:04:32,841] Trial 18 finished with value: 0.047154957306114714 and parameters: {'n_lags': 12, 'n_estimators': 182}. Best is trial 11 with value: 0.04601469301407499.
# [I 2024-06-13 03:04:35,484] Trial 19 finished with value: 0.04612491232065186 and parameters: {'n_lags': 5, 'n_estimators': 112}. Best is trial 11 with value: 0.04601469301407499.
# [I 2024-06-13 03:04:37,273] Trial 20 finished with value: 0.04600679658408037 and parameters: {'n_lags': 1, 'n_estimators': 162}. Best is trial 20 with value: 0.04600679658408037.
# [I 2024-06-13 03:04:39,571] Trial 21 finished with value: 0.04600971633552192 and parameters: {'n_lags': 1, 'n_estimators': 164}. Best is trial 20 with value: 0.04600679658408037.
# [I 2024-06-13 03:04:43,785] Trial 22 finished with value: 0.0461361851286705 and parameters: {'n_lags': 4, 'n_estimators': 156}. Best is trial 20 with value: 0.04600679658408037.
# [I 2024-06-13 03:04:49,971] Trial 23 finished with value: 0.047159062662973976 and parameters: {'n_lags': 10, 'n_estimators': 165}. Best is trial 20 with value: 0.04600679658408037.
# [I 2024-06-13 03:04:53,492] Trial 24 finished with value: 0.04619802253059237 and parameters: {'n_lags': 6, 'n_estimators': 112}. Best is trial 20 with value: 0.04600679658408037.
# [I 2024-06-13 03:04:57,442] Trial 25 finished with value: 0.04598215233633456 and parameters: {'n_lags': 3, 'n_estimators': 174}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:05:00,614] Trial 26 finished with value: 0.04598515653423038 and parameters: {'n_lags': 3, 'n_estimators': 177}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:05:09,290] Trial 27 finished with value: 0.04717827701449094 and parameters: {'n_lags': 10, 'n_estimators': 200}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:05:12,609] Trial 28 finished with value: 0.045982420971581575 and parameters: {'n_lags': 3, 'n_estimators': 186}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:05:23,270] Trial 29 finished with value: 0.04820598713223688 and parameters: {'n_lags': 15, 'n_estimators': 185}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:05:26,408] Trial 30 finished with value: 0.04598515653423038 and parameters: {'n_lags': 3, 'n_estimators': 177}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:05:30,264] Trial 31 finished with value: 0.04613500607700617 and parameters: {'n_lags': 4, 'n_estimators': 183}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:05:33,871] Trial 32 finished with value: 0.04598388290446002 and parameters: {'n_lags': 3, 'n_estimators': 175}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:05:38,462] Trial 33 finished with value: 0.04620654042522908 and parameters: {'n_lags': 6, 'n_estimators': 148}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:05:44,495] Trial 34 finished with value: 0.047169680749710494 and parameters: {'n_lags': 9, 'n_estimators': 174}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:05:49,158] Trial 35 finished with value: 0.04598402912914325 and parameters: {'n_lags': 3, 'n_estimators': 191}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:05:54,266] Trial 36 finished with value: 0.046206377483643105 and parameters: {'n_lags': 6, 'n_estimators': 195}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:05:57,665] Trial 37 finished with value: 0.04598339573918096 and parameters: {'n_lags': 3, 'n_estimators': 192}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:06:07,735] Trial 38 finished with value: 0.049249341679446584 and parameters: {'n_lags': 22, 'n_estimators': 131}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:06:14,850] Trial 39 finished with value: 0.04716042219869373 and parameters: {'n_lags': 12, 'n_estimators': 146}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:06:21,387] Trial 40 finished with value: 0.047239712149863694 and parameters: {'n_lags': 7, 'n_estimators': 171}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:06:24,722] Trial 41 finished with value: 0.04598313914757258 and parameters: {'n_lags': 3, 'n_estimators': 190}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:06:29,329] Trial 42 finished with value: 0.04598339573918096 and parameters: {'n_lags': 3, 'n_estimators': 192}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:06:33,808] Trial 43 finished with value: 0.046150128415089565 and parameters: {'n_lags': 5, 'n_estimators': 190}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:06:36,614] Trial 44 finished with value: 0.04598737942091236 and parameters: {'n_lags': 2, 'n_estimators': 193}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:06:56,024] Trial 45 finished with value: 0.050326521175895124 and parameters: {'n_lags': 29, 'n_estimators': 199}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:07:02,059] Trial 46 finished with value: 0.047253005336060874 and parameters: {'n_lags': 8, 'n_estimators': 185}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:07:05,751] Trial 47 finished with value: 0.046128505634348935 and parameters: {'n_lags': 5, 'n_estimators': 157}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:07:09,414] Trial 48 finished with value: 0.0459904718290835 and parameters: {'n_lags': 2, 'n_estimators': 168}. Best is trial 25 with value: 0.04598215233633456.
# [I 2024-06-13 03:07:14,005] Trial 49 finished with value: 0.04723597910695333 and parameters: {'n_lags': 7, 'n_estimators': 153}. Best is trial 25 with value: 0.04598215233633456.
# Best parameters: {'n_lags': 3, 'n_estimators': 174}
# Best trial value: 0.04598215233633456

# %% [markdown]
# **Sử dụng tham số tối ưu để huấn luyện mô hình cuối cùng**

# %%
optimal_n_lags = best_params['n_lags']
optimal_n_estimators = best_params['n_estimators']
lagged_data = create_lagged_features(data_scaled.flatten(), optimal_n_lags)

# %%
# Chia dữ liệu thành tập huấn luyện và kiểm tra
train_size = int(0.9 * len(lagged_data))
train_data, test_data = lagged_data[:train_size], lagged_data[train_size:]
# Tách các đặc trưng và mục tiêu
X_train, y_train = train_data.iloc[:, :-1], train_data.iloc[:, -1]
X_test, y_test = test_data.iloc[:, :-1], test_data.iloc[:, -1]

# %%
# Huấn luyện mô hình Random Forest với các tham số tối ưu
rf_model = RandomForestRegressor(n_estimators=optimal_n_estimators, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=174, random_state=42)

# %%
# Dự đoán trên tập kiểm tra
y_pred = rf_model.predict(X_test)

# %%
# Chuyển đổi lại dữ liệu về thang đo gốc
y_test_inverse = scaler.inverse_transform(y_test.values.reshape(-1, 1))
y_pred_inverse = scaler.inverse_transform(y_pred.reshape(-1, 1))

# %%
# Tính toán các độ đo lỗi
test_mape = mean_absolute_percentage_error(y_test_inverse, y_pred_inverse)
test_mse = mean_squared_error(y_test_inverse, y_pred_inverse)
test_rmse = np.sqrt(test_mse)

print(f"MAPE on Test dataset: {test_mape:.4f}")
print(f"RMSE on Test dataset: {test_rmse:.4f}")
print(f"MSE on Test dataset: {test_mse:.4f}")
# Out:
# MAPE on Test dataset: 0.0266
# RMSE on Test dataset: 17.7598
# MSE on Test dataset: 315.4121

# %%
# Hàm dự báo tương lai
def forecast_future(model, data, n_lags, n_periods):
    future_forecast = []
    last_values = data[-n_lags:]
    for _ in range(n_periods):
        prediction = model.predict(last_values.reshape(1, -1))[0]
        future_forecast.append(prediction)
        last_values = np.append(last_values[1:], prediction)
    return np.array(future_forecast)

# %%
# Dự báo giá trị tương lai
forecast_30_days = forecast_future(rf_model, data_scaled.flatten(), optimal_n_lags, 30)
forecast_60_days = forecast_future(rf_model, data_scaled.flatten(), optimal_n_lags, 60)
forecast_90_days = forecast_future(rf_model, data_scaled.flatten(), optimal_n_lags, 90)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
# Chuyển đổi dự báo về thang đo gốc
forecast_30_days_inverse = scaler.inverse_transform(forecast_30_days.reshape(-1, 1))
forecast_60_days_inverse = scaler.inverse_transform(forecast_60_days.reshape(-1, 1))
forecast_90_days_inverse = scaler.inverse_transform(forecast_90_days.reshape(-1, 1))

# %%
print('Predicted closing prices for the next 30 days:')
print(forecast_30_days_inverse.flatten())

print('Predicted closing prices for the next 60 days:')
print(forecast_60_days_inverse.flatten())

print('Predicted closing prices for the next 90 days:')
print(forecast_90_days_inverse.flatten())
# Out:
# Predicted closing prices for the next 30 days:
# [578.07728949 580.94892833 590.7911734  579.87501078 584.20471921
#  582.7349377  592.42674041 590.32199762 584.76601304 578.1660206
#  590.01999384 587.40181025 566.72898103 595.85107376 583.48747449
#  564.09271314 600.40009412 568.64203063 569.77180079 596.86543413
#  581.69878249 564.91730792 596.94381354 571.1127373  564.86875025
#  595.03655647 549.31549932 567.62955787 583.08852164 566.58442293]
# Predicted closing prices for the next 60 days:
# [578.07728949 580.94892833 590.7911734  579.87501078 584.20471921
#  582.7349377  592.42674041 590.32199762 584.76601304 578.1660206
#  590.01999384 587.40181025 566.72898103 595.85107376 583.48747449
#  564.09271314 600.40009412 568.64203063 569.77180079 596.86543413
#  581.69878249 564.91730792 596.94381354 571.1127373  564.86875025
#  595.03655647 549.31549932 567.62955787 583.08852164 566.58442293
#  585.98653225 588.36432698 584.3267831  586.75440221 585.86317876
#  591.65298566 587.72989555 575.9889737  589.85232047 581.02388758
#  569.49198605 587.87378939 586.53587944 581.63786703 588.25485853
#  581.83213192 593.71300357 584.63526512 583.64481683 587.33574632
#  591.0457816  592.87614843 577.80207845 582.12232782 584.19832114
#  578.76489667 596.25967864 589.4137777  567.53185132 594.35274489]
# Predicted closing prices for the next 90 days:
# [578.07728949 580.94892833 590.7911734  579.87501078 584.20471921
#  582.7349377  592.42674041 590.32199762 584.76601304 578.1660206
#  590.01999384 587.40181025 566.72898103 595.85107376 583.48747449
#  564.09271314 600.40009412 568.64203063 569.77180079 596.86543413
#  581.69878249 564.91730792 596.94381354 571.1127373  564.86875025
#  595.03655647 549.31549932 567.62955787 583.08852164 566.58442293
#  585.98653225 588.36432698 584.3267831  586.75440221 585.86317876
#  591.65298566 587.72989555 575.9889737  589.85232047 581.02388758
#  569.49198605 587.87378939 586.53587944 581.63786703 588.25485853
#  581.83213192 593.71300357 584.63526512 583.64481683 587.33574632
#  591.0457816  592.87614843 577.80207845 582.12232782 584.19832114
#  578.76489667 596.25967864 589.4137777  567.53185132 594.35274489
#  584.59508893 564.41507803 596.79723832 570.19887787 565.28341539
#  593.88256371 549.91727194 567.52646739 579.27266768 565.6805982
#  585.25683102 567.68614084 588.35325408 583.69232495 581.89258219
#  587.90803082 587.27944911 591.77424745 587.99164271 575.03165728
#  589.85232047 580.42903368 567.28454301 591.64298739 588.84834541
#  566.05874061 595.36034411 570.72873683 564.58489679 594.57368795]

# %%
# Tạo index cho các dự đoán tiếp theo
last_date = df.index[-1]
index_next_30_days = pd.date_range(last_date + pd.Timedelta(days=1), periods=30, freq='D')
index_next_60_days = pd.date_range(last_date + pd.Timedelta(days=1), periods=60, freq='D')
index_next_90_days = pd.date_range(last_date + pd.Timedelta(days=1), periods=90, freq='D')

# %%
# Vẽ đồ thị cho dự đoán 30 ngày
plt.figure(figsize=(16, 5)),
plt.plot(df.index[:train_size], scaler.inverse_transform(train_data['target'].values.reshape(-1, 1)),
         color='blue', linestyle='-', label='Train')
plt.plot(df.index[train_size:train_size + len(y_test)], y_test_inverse, color='red', linestyle='-', label='Test')
plt.plot(df.index[train_size:train_size + len(y_test)], y_pred_inverse, color='purple', linestyle='-', label='Predicted Test')
plt.plot(index_next_30_days, forecast_30_days_inverse, color='green', linestyle='-', label='Forecast_30_Days')
plt.legend()
plt.grid()
plt.title(f"BNB Closing Price Data from {df.index[0].strftime('%Y-%m-%d')} to {index_next_30_days[-1].strftime('%Y-%m-%d')}")
plt.xlabel("Date")
plt.ylabel("Close value")
plt.savefig('RandomForest_BNB_30days_91.png')
plt.show()

# %%
# Vẽ đồ thị cho dự đoán 60 ngày
plt.figure(figsize=(16, 5))
plt.plot(df.index[:train_size], scaler.inverse_transform(train_data['target'].values.reshape(-1, 1)),
         color='blue', linestyle='-', label='Train')
plt.plot(df.index[train_size:train_size + len(y_test)], y_test_inverse, color='red', linestyle='-', label='Test')
plt.plot(df.index[train_size:train_size + len(y_test)], y_pred_inverse, color='purple', linestyle='-', label='Predicted Test')
plt.plot(index_next_60_days, forecast_60_days_inverse, color='yellow', linestyle='-', label='Forecast_60_Days')
plt.legend()
plt.grid()
plt.title(f"BNB Closing Price Data from {df.index[0].strftime('%Y-%m-%d')} to {index_next_60_days[-1].strftime('%Y-%m-%d')}")
plt.xlabel("Date")
plt.ylabel("Close value")
plt.savefig('RandomForest_BNB_60days_91.png')
plt.show()

# %%
# Vẽ đồ thị cho dự đoán 90 ngày
plt.figure(figsize=(16, 5))
plt.plot(df.index[:train_size], scaler.inverse_transform(train_data['target'].values.reshape(-1, 1)),
         color='blue', linestyle='-', label='Train')
plt.plot(df.index[train_size:train_size + len(y_test)], y_test_inverse, color='red', linestyle='-', label='Test')
plt.plot(df.index[train_size:train_size + len(y_test)], y_pred_inverse, color='purple', linestyle='-', label='Predicted Test')
plt.plot(index_next_90_days, forecast_90_days_inverse, color='black', linestyle='-', label='Forecast_90_Days')
plt.legend()
plt.grid()
plt.title(f"BNB Closing Price Data from {df.index[0].strftime('%Y-%m-%d')} to {index_next_90_days[-1].strftime('%Y-%m-%d')}")
plt.xlabel("Date")
plt.ylabel("Close value")
plt.savefig('RandomForest_BNB_90days_91.png')
plt.show()
